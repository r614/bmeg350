# %%
from helper import generate_random_ndt_motion
import matplotlib.pyplot as plt


curve1 = generate_random_ndt_motion()
plt.figure()
plt.plot(
    curve1[:, 0],   # x-coordinates.
    curve1[:, 1]    # y-coordinates.
)

plt.grid()
plt.show()
